# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.4/618.4 kB 10.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 251MB/s]

# %%
# !touch data.yaml

# %%
model.train(data = "/content/data.yaml", epochs = 10)
# Out:
# Ultralytics YOLOv8.0.186 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train3/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images" , save = True, save_txt = True)
# Out:
# image 1/8 /content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images/ezgif-frame-001_jpg.rf.17acdc5f6a6e2b1d66869d8bc48af3d1.jpg: 640x640 3 OLEANDERs, 39.6ms
# image 2/8 /content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images/ezgif-frame-001_jpg.rf.e226f059212acecf2f61418ba6065a57.jpg: 640x640 1 CALOTROPIS, 36.2ms
# image 3/8 /content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images/ezgif-frame-012_jpg.rf.4fea043d71451ce06c94e68d2d5937be.jpg: 640x640 1 Calotropis, 39.9ms
# image 4/8 /content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images/ezgif-frame-033_jpg.rf.047b3e546fcd9e08b301536f1791af15.jpg: 640x640 1 Azadiractha Indica, 1 OLEANDER, 36.4ms
# image 5/8 /content/drive/MyDrive/data_Plants/Medical_Plants.v1-medical_plants.yolov8/test/images/ezgif-frame-042_jpg.rf.eede5994fc6654ea79ecd1c0979791f7.jpg: 640x640 1 LEAVS, 1 OLEANDER, 36.2ms
# ...
